# %% [markdown]
# # DATA SCIENCE AND BUSINESS ANALYTICS INTERNSHIP @GRIP The Sparks Foundation

# %% [markdown]
# # TASK-3 : Exploratory Data Analysis- Retail - on Sample superstore data

# %% [markdown]
# # by- Deepika Bisht

# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#loading dataset
df=pd.read_csv("SampleSuperstore.csv")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F5F69E37F0>,
# ...
#       dtype=object)

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(6,5))
sns.kdeplot(df['Sales'],color='red',label='SALES',shade=True)
sns.kdeplot(df['Profit'],color='Blue',label='PROFIT', shade=True)
plt.xlim([-100,1000])
plt.legend()
plt.show()

# %% [markdown]
# Here, we can see that Profit is more tham sales but in some areas profit can still be increased.

# %% [markdown]
# # Analysis using Pairplot of each column

# %% [markdown]
# ### <font color=blue>1. Based on the Catagory</font>

# %%
sns.pairplot(df,hue='Category')

# %% [markdown]
# ### <font color= blue >2. Based on Region </font>

# %%
sns.pairplot(df,hue='Region')

# %% [markdown]
# ### <font color= Blue>3. Based on the segment</font>

# %%
sns.pairplot(df,hue="Segment")

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(df.corr(), cmap='rocket_r', annot=True)

# %% [markdown]
# From above Heatmap:
#
# -Sales and Profit are Moderately Correlated, Discount and Profit are Negatively Correlated whereas Quantity and Profit are less Moderately Correlated.

# %% [markdown]
# # Statewise deal Analysis

# %%
df1 = df['State'].value_counts()
df1.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
df1.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('States')

plt.title('State Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
#  states with highest deals are California, New York and Texas.
#  state with least deals is Wyoming

# %%
df['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# Average number of deal per State is 204.

# %% [markdown]
# # City Wise analysis of the dealing

# %%
df2 = df['City'].value_counts()
df2=df2.head(50)
df2.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency / Number of deals')
plt.xlabel('City')

plt.title('City Wise Dealings', fontsize = 20)
plt.show()

# %% [markdown]
# New York city gets highest deals whereas Providence gets the least deal.

# %%
df['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %% [markdown]
# Average number of deal per city is 19

# %% [markdown]
# ###  Segment wise analysis of Profit, Discount and sales

# %%
df_segment= df.groupby(['Segment'])[['Sales', 'Discount', 'Profit']].mean()
df_segment
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %%
df_segment.plot.pie(subplots=True, 
                    autopct='%1.1f%%',
                    figsize=(20, 20),
                    startangle=90,         # start angle 90° (Africa)
                    shadow=True,
                    labels = df_segment.index)
plt.title('Segment wise analysis of Sale, Discount, profit')
# Out:
# Text(0.5, 1.0, 'Segment wise analysis of Sale, Discount, profit')

# %% [markdown]
# Sales:
# Consumer : 32%
# Corporate - 33.5%
# Home Office : 34.5%
#
#
# Discount :
# Consumer : 15.8%
# Corporate : 15.8%
# Home Office : 14.7%
#
#
# Profit :
# Consumer : 15.8%
# Corporate : 15.8%
# Home Office : 14.7%

# %% [markdown]
# ### Statewise analysis of Profit Discount and sales

# %%
df_state= df.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
df_state
# Out:
#                             Sales  Discount      Profit
# State
# Alabama                319.846557  0.000000   94.865989
# Arizona                157.508933  0.303571  -15.303235
# Arkansas               194.635500  0.000000   66.811452
# California             228.729451  0.072764   38.171608
# Colorado               176.418231  0.316484  -35.867351
# Connecticut            163.223866  0.007317   42.823071
# Delaware               285.948635  0.006250  103.930988
# District of Columbia   286.502000  0.000000  105.958930
# Florida                233.612815  0.299347   -8.875461
# Georgia                266.825217  0.000000   88.315453
# Idaho                  208.689810  0.085714   39.367767
# Illinois               162.939230  0.390041  -25.625787
# Indiana                359.431946  0.000000  123.375411
# Iowa                   152.658667  0.000000   39.460397
# Kansas                 121.429583  0.000000   34.851813
# Kentucky               263.250000  0.000000   80.573357
# ...

# %%
#STATEWISE ANALYSIS OF PROFIT

df_state1=df_state.sort_values('Profit')

df_state1[['Profit']].plot(kind = 'bar', color='green' ,figsize = (12,5))
plt.title('State wise Profit Analysis', fontsize = 30)
plt.ylabel('Profit per Sate')
plt.xlabel('States')
plt.show()

# %% [markdown]
# VERMONT has the highest profit while OHIO has the lowest profit

# %%
# STATEWISE ANALYSIS OF SALES


df_state[["Sales"]].plot(kind = 'bar',color="orange" ,figsize = (15,4))
plt.title('State wise sales Analysis', fontsize = 20)
plt.ylabel('Sales per Sate')
plt.xlabel('States')
plt.show()

# %% [markdown]
# WYOMING has the highest amount of sales whereas South Dakota has the lowest amount of Sales

# %%
# STATEWISE ANALYSIS OF DISCOUNT

df_state1['Discount'].plot(kind='bar',figsize=(15,5))
plt.title('State wise analysis of Discount', fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Discount')

# %% [markdown]
# ### CATEGORY WISE SALES DISCOUNT AND PROFIT

# %%
df_category = df.groupby(['Category'])[['Sales', 'Discount', 'Profit']].mean()
df_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
#sales
#Discount
#Profit

df_category.plot.pie(subplots=True, 
                     figsize=(18, 20), 
                     autopct='%1.1f%%', 
                     labels = df_category.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001F580101F10>,
# ...
#       dtype=object)

# %% [markdown]
# -Maximum sales and profit comes from Technology
# -Minimum Profit is obtained from Furniture

# %% [markdown]
# ### Sub-Category wise Sales, Profit and Discount

# %%
df_sub_category = df.groupby(['Sub-Category'])[['Sales', 'Discount', 'Profit']].mean()
df_sub_category
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918
# Labels          34.303055  0.068681   15.236962
# Machines      1645.553313  0.306087   29.432669
# Paper           57.284092  0.074891   24.856620
# Phones         371.211534  0.154556   50.073938
# Storage        264.590553  0.074704   25.152277
# Supplies       245.650200  0.076842   -6.258418
# Tables         648.794771  0.261285  -55.565771

# %% [markdown]
# #### 1) BASED ON THE SALES

# %%
plt.figure(figsize = (15,15))
plt.pie(df_sub_category['Sales'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Sales Analysis', fontsize = 20)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Copier and Machine have High sales

# %% [markdown]
# #### 2) BASED ON THE DISCOUNT

# %%
plt.figure(figsize = (15,15))
plt.pie(df_sub_category['Discount'], labels = df_sub_category.index, autopct = '%1.1f%%')
plt.title('Sub-Category Wise Discount Analysis', fontsize = 30)
plt.legend()
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Binders , Machines and tables have highest Discount.

# %% [markdown]
# #### 3) BASED ON THE PROFIT

# %%
df_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',figsize= (10,5),label=['Avg Sales Price($)','Profit($)'])

# %% [markdown]
# # INTERPRETATIONS
#
# ###  -Profit is more than that of sale but there are some areas where profit could be increased.
# ###  Relationship between sales, profit and discount
# - Sales and Profit are Moderately Correlated.
# - Quantity and Profit are less Moderately Correlated.
# - Discount and Profit are Negatively Correlated
# ###  Statewise deal analysis:
# - California, New York and Texas are states with highest deals.
# - Wyoming has least number of deals.
# - Average number of deal per State is 204
# ###  Citywise deal analysis:
# - New York City gets highest deals
# - Providence  city gets the least deal.
# - Average number of deal per city is 19
# ###  Segment wise:
# - Home Office contribute more to sales.
# - For Discount, Consumers  and Corporates contribute equally but more than Home office.
# - Similarly, Consumers and Corportes contribute equally to Profits but more than Home office.
# ###  Statewise profit analysis :
# - Vermont has the highest profit while Ohio has the lowest profit
# ###  Statewise sales analysis:
# - Wyoming has the highest amount of sales whereas South Dakota has the lowest amount of Sales.
# ###  Statewise discount analysis:
# - Ilinois state has the highest discount.
# ### Category wise  sales, discount and profit:
# - Maximum sales and profit comes from Technology
# - Minimum Profit is obtained from Furniture
# ### Sub-Category wise Sales, Profit and Discount:
# - Copier: Highest Profit & sales
# - Binders , Machines and tables have high Discount
